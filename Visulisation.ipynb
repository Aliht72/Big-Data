# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import operator

df1 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/ad-clicks.csv")

df1['adId'] = df1['adId'].apply(str)
df2 =  df1['adCategory'] + ' - ' + df1['adId']
Grouping =df1.groupby(['adId', 'adCategory']).size().reset_index(name='counts')
print(Grouping.sort_values(by='adCategory', ascending=True))
"""print(Counter(df2).keys())# equals to list(set(words))
print(Counter(df2).values()) # counts the elements' frequency"""
# Out:
#    adId   adCategory  counts
# 22   29   automotive     566
# 17   24     clothing     604
# 8    16     clothing     564
# 13   20     clothing     609
# 11   19     clothing     563
# 25    5    computers     534
# 18   25    computers     503
# 4    12    computers     535
# 5    13    computers     496
# 15   22    computers     570
# 23    3  electronics     565
# 12    2  electronics     532
# 16   23      fashion     597
# 6    14      fashion     593
# 2    10      fashion     537
# 24    4        games     492
# 9    17        games     525
# 3    11        games     509
# 20   27        games     532
# 10   18        games     543
# 28    8     hardware     534
# 21   28     hardware     519
# 27    7     hardware     535
# 26    6       movies     583
# 19   26       movies     540
# 14   21       movies     569
# 0     0       sports     524
# 1     1       sports     507
# 7    15       sports     502
# 29    9       sports     541
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = ['Electronics', 'Movies', 'Computers' , "Clothing" , "Games" , "Automotive" , "sports"  , "Hardware","Fashion" ]
Electronics = np.array([532, 565 , 0 , 0 , 0])
Movies = np.array([569, 583 ,540 , 0 , 0])
Computers = np.array([503, 535, 496, 534 , 570])
Clothing = np.array([609, 564, 604 ,563 , 0])
Games = np.array([ 492,525, 509, 543 , 532])
Automotive = np.array([ 566,0 , 0 , 0, 0])
sports = np.array([ 541 , 502 ,507 ,524 , 0])
Hardware = np.array([ 535 ,519, 534 , 0 , 0 ])
Fashion = np.array([ 537 ,597 , 593 , 0 , 0 ])



y1 =np.array([532, 569 , 503 , 609 , 492 ,566 ,541, 535 , 537 ])
y2 = np.array([565 , 583 , 535 , 564 ,  525 , 0 ,502 , 519 ,597 ])
y3 =np.array([0 , 540 , 496 ,604 , 509 ,  0 , 507 ,534 ,593 ])
y4 =np.array([0 , 0 , 534 ,563 , 543 ,  0 , 524 ,0 , 0 ])
y5 =np.array([0 , 0 ,  570 , 0  , 532 ,  0 , 0 ,0 ,0 ])


# plot bars in stack manner
plt.bar(x, y1, color='blue' )
plt.bar(x, y2, bottom= y1 , color='orange')
plt.bar(x, y3, bottom= y1+ y2 , color='yellow')
plt.bar(x, y4, bottom= y1+ y2 +y3 , color='gray')
plt.bar(x, y5, bottom= y1+ y2 +y3 +y4 , color='indigo')





plt.xlabel("Catagories")
plt.ylabel("Number of Adds ")
plt.title("Advertise catagories by their differenet add-id")
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import operator
df_1 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/buy-clicks.csv")
df_1.groupby('buyId').size()
Price_id =df_1.groupby('buyId').sum()
print(Price_id)
# Out:
#            txId  userSessionId   team  userId    price
# buyId
# 0      15071080       13546442  42962  710892    592.0
# 1       6790676        6095271  18472  317670    538.0
# 2      18165871       16252202  50301  820870   2142.0
# 3       8447044        7605052  23545  411539   1685.0
# 4      11222443       10154777  30129  526393   4250.0
# 5      15283439       13787621  41821  712078  12200.0

# %%
import matplotlib.pyplot as plt
 
 
# Creating dataset
products = ['0', '1', '2',
        '3', '4', '5']
 
data = Price_id["price"]
 
 
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
 
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
 
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d})".format(pct, absolute)
 
# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = products,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
# Adding legend
ax.legend(wedges, products,
          title ="Products Id",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import operator
df_3 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/game-clicks.csv")


New_column = 1 
df_3["New_column"] = New_column
df_3["timestamp"] = pd.to_datetime(df_3["timestamp"])

df_3["Time"] = df_3["timestamp"].dt.time





Daily = df_3.groupby([pd.Grouper(key='timestamp',freq='1D'),df_3.New_column]).size().reset_index(name='count')
Daily= Daily.drop([0 , 21])

# %%
import matplotlib.pyplot as plt

Days = Daily["timestamp"]
Counts = Daily["count"]
  
plt.plot(Days, Counts, color='red')
plt.title('Daily clicks count', fontsize=14)
plt.xlabel('Days', fontsize=14)
plt.ylabel('Number of clicks', fontsize=14)
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import operator
df_4 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/level-events.csv")
TeamId = df_4.groupby(["teamId"]).size().reset_index(name='counts')
TeamId["counts"] = (TeamId["counts"]/2)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
 
# Creating dataset
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot(TeamId["counts"])
plt.title('Number of teams participating in events ', fontsize=14)

# show plot
plt.show()

# %%
import pandas as pd
import operator
df_5 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/team-assignments.csv")
User_change = df_5.groupby(["userId"]).size().reset_index(name='counts')
User_change['counts'] = User_change['counts'].apply(str)
User_changes = User_change.groupby(["counts"]).size().reset_index(name='count')

# %%
User_changes["counts"]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

Changes =["One" , "Two" , "Three", "Four" , "Five" , "Six or more"]
Number=[425 , 206 , 299 , 406, 396 , 317+210+86+36+6+4]
ax.bar(Changes,Number)
plt.show()

# %%
import pandas as pd
import operator
import datetime
df_7 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/users.csv")
df_8 = pd.read_csv(r"/Users/ali/Desktop/BDM-Project/DataSet/flamingo-data/user-session.csv")
Device =df_8.groupby(['platformType']).size().reset_index(name='counts')
print(Device)
# Out:
#   platformType  counts
# 0      android    3274
# 1       iphone    3874
# 2        linux     504
# 3          mac     358
# 4      windows    1240

# %%
import matplotlib.pyplot as plt
import numpy as np

mylabels = ["Android", "Iphone", "Linux", "Mac" , "Windows"]
explode = (0, 0.1, 0, 0, 0) 
fig1, ax1 = plt.subplots()

ax1.pie(Device["counts"], explode=explode, labels=mylabels, autopct='%1.1f%%',
        shadow=True, startangle=90)



ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
NDF_1 = pd.DataFrame(data =df_7["userId"] )
NDF_1["country"] = df_7["country"]
NDF_2 = pd.DataFrame(data =df_8["userId"] )
NDF_2["platformType"] = df_8["platformType"]
NDF_3 = pd.merge(NDF_1, NDF_2, on='userId')

# %%
NDF_4 = NDF_3.groupby(['platformType',"country"]).size().reset_index(name='counts')
NDF_5 = NDF_4[NDF_4['country'] == ("FR")]
import matplotlib.pyplot as plt
import numpy as np

mylabels = ("Android" ,"iphone" , "windows" )
myexplode = [0.2, 0, 0, 0]

plt.pie(NDF_5["counts"],   labels = mylabels,shadow = True)
plt.show()

# %%
NDF_5["counts"]
# Out:
# 60     24
# 263    14
# 542    14
# Name: counts, dtype: int64
